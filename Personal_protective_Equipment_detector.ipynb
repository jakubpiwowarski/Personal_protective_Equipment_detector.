# %% [markdown]
# <a href="https://colab.research.google.com/github/jakubpiwowarski/Personal_protective_Equipment_detector./blob/main/Personal_protective_Equipment_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Jun 22 08:11:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 19.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:01<00:00, 72.6MB/s]
# Ultralytics YOLOv8.0.121 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients
#
# ...
# 100% 476k/476k [00:00<00:00, 22.9MB/s]
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 61.3ms
# Speed: 13.2ms preprocess, 61.3ms inference, 20.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !yolo task=detect mode=train model=yolov8l.pt  data=../content/drive/MyDrive/101-Object_Detection/Pliki/Project_3-PPE_Detection/ConstructionSiteSafety/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.121 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
